# %%
# !nvidia-smi
# Out:
# Wed Feb 25 14:13:21 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             14W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# !ls
# Out:
# Mounted at /content/drive
# drive  sample_data

# %%
# %cd ./drive/MyDrive/ColabNotebooks
# Out:
# /content/drive/MyDrive/ColabNotebooks

# %%
# !ls
# Out:
# edge_detection.h	  hello		  lagopontini.ppm  Untitled0.ipynb
# edge_detection_kernel.cu  hello_world.cu  main.cu

# %%
# !nvcc -arch=sm_75 -std=c++11 -O3 -c edge_detection_kernel.cu

# %%
# !nvcc -arch=sm_75 -std=c++11 -O3 -c main.cu
# Out:
# main.cu(24): warning #1650-D: result of call is not used
#       fscanf(fp, "%s", magic);
#       ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# main.cu(27): warning #1650-D: result of call is not used
#       fscanf(fp, "%d %d %d", &width, &height, &maxval);
#       ^
#
# main.cu(39): warning #1650-D: result of call is not used
#       fread(img->data, 1, size, fp);
#       ^
#
# main.cu(24): warning #1650-D: result of call is not used
#       fscanf(fp, "%s", magic);
#       ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# main.cu(27): warning #1650-D: result of call is not used
#       fscanf(fp, "%d %d %d", &width, &height, &maxval);
#       ^
#
# main.cu(39): warning #1650-D: result of call is not used
#       fread(img->data, 1, size, fp);
#       ^
#
# main.cu: In function ‘Image* read_ppm(const char*)’:
# main.cu:24:7: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#    24 |     fscanf(fp, "%s", magic);
#       |     ~~^~~~~~~~~~~~~~~~~
# main.cu:27:7: warning: ignoring return value of ‘int fscanf(FILE*, const char*, ...)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#    27 |     fscanf(fp, "%d %d %d", &width, &height, &maxval);
#       |     ~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# main.cu:39:6: warning: ignoring return value of ‘size_t fread(void*, size_t, size_t, FILE*)’ declared with attribute ‘warn_unused_result’ [-Wunused-result]
#    39 |     fread(img->data, 1, size, fp);
#       |     ~^~~~~~~~~~~~~~~~~~~~~~~~

# %%
# !nvcc -arch=sm_75 -std=c++11 -O3 edge_detection_kernel.o main.o -o edge_detection -lcufft

# %%
# !./edge_detection lagopontini.ppm result.ppm laplacian
# Out:
# ========== EDGE DETECTION VIA FFT ==========
# Input:  lagopontini.ppm
# Output: result.ppm
# Method: laplacian
# ==========================================
#
# Image loaded: 1280 x 720
# Converting RGB to grayscale...
# Running edge detection (laplacian)...
# Output saved: result.ppm
#
#
# ========== PERFORMANCE METRICS ==========
# Image size: 1280 x 720 (921600 pixels)
# FFT Forward:      0.203 ms
# Kernel Multiply:  0.324 ms
# FFT Inverse:      0.192 ms
# Magnitude/Clip:   0.042 ms
# ----------------------------------------
# TOTAL TIME:       0.761 ms
# Estimated BW:     19.38 GB/s
# =========================================

# %%
# !./main lagopontini.ppm result.ppm sobel
# Out:
# /bin/bash: line 1: ./main: No such file or directory
